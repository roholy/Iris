# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
iris = pd.read_csv("https://raw.githubusercontent.com/roholy/Iris/main/Data/iris%20(1).csv")
fig=sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', kind="reg", color='red', data=iris) #reg adds regression and kernel density
plt.show()

#Write a Python program to create a joinplot and add regression and kernel density fits using “reg” to describe individual distributions on the same plot between Sepal length and Sepal width.
