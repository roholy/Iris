# %%
#Write a Python program using seaborne to create a kde (Kernel Density Estimate) plot of two shaded bivariate densities of Sepal Width and Sepal Length.

# Import necessary modules 
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt 
iris = pd.read_csv("https://raw.githubusercontent.com/roholy/Iris/main/Data/iris%20(1).csv")
#Drop id column
iris = iris.drop('Id',axis=1)
#Need to add the sub variable manually, and delete the cmap='plasma' in kdeplot
# sub=iris[iris['Species']=='Iris-setosa']
#delete the cmap='plasma' in kdeplot
# sns.kdeplot(data=sub[['PetalLengthCm','PetalWidthCm']], shade=True, shade_lowest=False)


# x = sub['SepialLengthCm'] #calls the function sub which takes the column out of data
# y = sub['SepalWidthCm']
sns.displot(iris, x='SepialLengthCm', y='SepalWidthCm', hue = 'Species')

#sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="Species")

# sns.kdeplot(
#     data=geyser, x="waiting", y="duration", hue="kind", fill=True,
# )



plt.title('Iris-setosa')
plt.xlabel('Petal Length Cm')
plt.ylabel('Petal Width Cm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-436695989976> in <module>
#      17 # x = sub['SepialLengthCm'] #calls the function sub which takes the column out of data
#      18 # y = sub['SepalWidthCm']
# ---> 19 sns.displot(iris, x='SepialLengthCm', y='SepalWidthCm', hue = 'Species')
#      20
#      21 #sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="Species")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2146     p = _DistributionFacetPlotter(
#    2147         data=data,
# -> 2148         variables=_DistributionFacetPlotter.get_semantics(locals())
#    2149     )
#    2150
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py in __init__(self, data, variables)
#     106     ):
#     107
# --> 108         super().__init__(data=data, variables=variables)
#     109
#     110     @property
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     885                     # We don't know what this name means
#     886                     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 887                     raise ValueError(err)
#     888
#     889             else:
#
# ValueError: Could not interpret value `SepialLengthCm` for parameter `x`

# %%
sns.kdeplot(data['mpg'],data['qsec'],shade=True,cmap="Purples_d")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9acc9dd4d058> in <module>
# ----> 1 sns.kdeplot(data['mpg'],data['qsec'],shade=True,cmap="Purples_d")
#       2 plt.show()
#
# NameError: name 'data' is not defined

# %%
# Import necessary modules 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
iris = pd.read_csv('https://raw.githubusercontent.com/roholy/Iris/main/Data/iris%20(1).csv')
#Drop id column

sub=iris[iris['Species']=='Iris-setosa']
#added sub function from other questions
iris = iris.drop('Id',axis=1)
# sns.kdeplot(data=sub[['PetalLengthCm','PetalWidthCm']], shade=True, shade_lowest=False)
x = sub['SepalWidthCm'] #calls the function sub which takes the column out of data
y = sub['SepalLengthCm']
sns.kdeplot(x,y,shade=True)
plt.title('Iris-setosa')
plt.xlabel('SepalWidthCm')
plt.ylabel('SepalLengthCm')
plt.show()
